# %%
import requests
import datetime
import json


SUMMARY_INDEX = "gracc.osg.summary"
ENDPOINT = "https://gracc.opensciencegrid.org:443/q"
HEADERS = {
    'Content-Type': 'application/json'
}


query = {

    "size": 100,
    # Get the latest record
    "sort": [
        {
            "EndTime": {
                "order": "desc"
            }
        }
    ],
}

response_json = requests.get(f"{ENDPOINT}/{SUMMARY_INDEX}/_search", data=json.dumps(query), headers=HEADERS).json()

response_json
# Out:
# {'took': 73,
#  'timed_out': False,
#  '_shards': {'total': 28, 'successful': 28, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': None,
#   'hits': [{'_index': 'gracc.osg.summary4-2024',
#     '_id': '545cb9b56c458c87087eac8ad529a5a2',
#     '_score': None,
#     '_source': {'OIM_WLCGAPELNormalFactor': 11.72,
#      'CoreHours': 5.313055555555556,
#      'WallDuration': 19127.0,
#      'OIM_ResourceGroup': 'MIT_CMS',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'MIT_CMS_3',
#      'OIM_Match': 'ProbeName-FQDN',
#      'DN': '/DC=ch/DC=cern/OU=Organic Units/OU=Users/CN=sciaba/CN=430796/CN=Andrea Sciaba',
#      'VOName': 'cms',
#      'OIM_WLCGAPELNormalizedWallDuration': 224168.44,
#      'CommonName': 'N/A',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Batch", "CommonName": "N/A", "Host_description": "N/A", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "cms", "ProbeName": "condor:ce03.cmsaf.mit.edu", "SiteName": "MIT_CMS_3", "WallDuration": 19127.0, "CpuDuration_user": 13402.0, "CpuDuration_system": 3020.0, "CoreHours": 5.313055555555556, "Njobs": 168.0, "CpuDuration": 16422.0, "Count": 168, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "cms", "ProjectName": "cms", "DN": "/DC=ch/DC=cern/OU=Organic Units/OU=Users/CN=sciaba/CN=430796/CN=Andrea Sciaba", "RawVOName": "/cms/Role=lcgadmin/Capability=NULL", "RawCorrectedReportableVOName": "", "RawProjectName": "N/A", "RawOIM_Site": "", "OIM_FieldOfScience": "High Energy Physics", "OIM_Facility": "Massachusetts Institute of Technology", "OIM_Site": "MIT CMS", "OIM_ResourceGroup": "MIT_CMS", "OIM_Resource": "MIT_CMS_3", "OIM_ID": "785", "OIM_FQDN": "ce03.cmsaf.mit.edu", "OIM_WLCGAccountingName": "T2_US_MIT", "OIM_WLCGAPELNormalFactor": 11.72, "OIM_Match": "ProbeName-FQDN", "OIM_UsageModel": "DEDICATED", "OIM_NSFFieldOfScience": "Physics", "OIM_WLCGAPELNormalizedWallDuration": 224168.44, "OIM_WLCGAPELNormalizedCpuDuration": 192465.84, "GPUHours": 0.0}'},
#      '@received': '2024-10-03T13:21:58.457898433Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 16422.0,
#      'OIM_Site': 'MIT CMS',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 1,
#      'OIM_WLCGAccountingName': 'T2_US_MIT',
#      'Count': 168,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'DEDICATED',
#      'GPUs': '0',
#      'CpuDuration_system': 3020.0,
#      'checksum': '545cb9b56c458c87087eac8ad529a5a2',
#      'CpuDuration_user': 13402.0,
#      'ReportableVOName': 'cms',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'N/A',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Batch',
#      'ProbeName': 'condor:ce03.cmsaf.mit.edu',
#      'OIM_WLCGAPELNormalizedCpuDuration': 192465.84,
#      'OIM_Facility': 'Massachusetts Institute of Technology',
#      'OIM_FieldOfScience': 'High Energy Physics',
#      'OIM_ID': '785',
#      'Host_description': 'N/A',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'cms',
#      'SiteName': 'MIT_CMS_3',
#      'Njobs': 168.0,
#      'RawVOName': '/cms/Role=lcgadmin/Capability=NULL',
#      'OIM_FQDN': 'ce03.cmsaf.mit.edu',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '3be71a8b5ff1913ceb7757e6192ff732',
#     '_score': None,
#     '_source': {'CoreHours': 329.6333333333333,
#      'WallDuration': 296670.0,
#      'OIM_ResourceGroup': 'BNL-SDCC',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'BNL-SDCC-CE02',
#      'OIM_PIName': 'Thomas Robert Junk',
#      'OIM_Organization': 'DUNE',
#      'OIM_Match': 'ProbeName-FQDN',
#      'DN': '/DC=org/DC=incommon/C=US/ST=Illinois/O=Fermi Research Alliance/CN=pilot-gpfrontend01.fnal.gov',
#      'VOName': 'dune',
#      'event': {'original': '{"Processors": 4, "GPUs": "0", "ResourceType": "Batch", "CommonName": "N/A", "Host_description": "N/A", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "dune", "ProbeName": "htcondor-ce:spce02.sdcc.bnl.gov", "SiteName": "BNL-SDCC-CE02", "WallDuration": 296670.0, "CpuDuration_user": 246963.0, "CpuDuration_system": 86182.0, "CoreHours": 329.6333333333333, "Njobs": 28.0, "CpuDuration": 333145.0, "Count": 28, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "dune", "ProjectName": "dune", "DN": "/DC=org/DC=incommon/C=US/ST=Illinois/O=Fermi Research Alliance/CN=pilot-gpfrontend01.fnal.gov", "RawVOName": "/dune/Role=pilot/Capability=NULL", "RawCorrectedReportableVOName": "", "RawProjectName": "N/A", "RawOIM_Site": "", "OIM_FieldOfScience": "High Energy Physics", "OIM_PIName": "Thomas Robert Junk", "OIM_Organization": "DUNE", "OIM_Department": "N/A", "OIM_Facility": "Brookhaven National Laboratory", "OIM_Site": "BNL-SDCC", "OIM_ResourceGroup": "BNL-SDCC", "OIM_Resource": "BNL-SDCC-CE02", "OIM_ID": "1248", "OIM_FQDN": "spce02.sdcc.bnl.gov", "OIM_Match": "ProbeName-FQDN", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:21:59.122908154Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 333145.0,
#      'OIM_Site': 'BNL-SDCC',
#      'OIM_Department': 'N/A',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 4,
#      'Count': 28,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 86182.0,
#      'checksum': '3be71a8b5ff1913ceb7757e6192ff732',
#      'CpuDuration_user': 246963.0,
#      'ReportableVOName': 'dune',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'N/A',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Batch',
#      'ProbeName': 'htcondor-ce:spce02.sdcc.bnl.gov',
#      'OIM_Facility': 'Brookhaven National Laboratory',
#      'OIM_FieldOfScience': 'High Energy Physics',
#      'OIM_ID': '1248',
#      'Host_description': 'N/A',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'dune',
#      'SiteName': 'BNL-SDCC-CE02',
#      'Njobs': 28.0,
#      'RawVOName': '/dune/Role=pilot/Capability=NULL',
#      'OIM_FQDN': 'spce02.sdcc.bnl.gov',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': 'd83d8424a73bb69263a8c33f4550812f',
#     '_score': None,
#     '_source': {'CoreHours': 726.0552777777777,
#      'WallDuration': 2613799.0,
#      'OIM_ResourceGroup': 'UA-LR-ITS',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'UA-LR-ITS-EP',
#      'OIM_PIName': 'Maurizio Ungaro',
#      'OIM_Organization': 'Jefferson Lab',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=gemc',
#      'VOName': 'jlab',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "UA-LR-ITS-EP", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "jlab", "ProbeName": "condor-ap:scosg2202.jlab.org", "SiteName": "JLAB", "WallDuration": 2613799.0, "CpuDuration_user": 2131514.0, "CpuDuration_system": 3696.0, "CoreHours": 726.0552777777777, "Njobs": 40.0, "CpuDuration": 2135210.0, "Count": 40, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "jlab", "ProjectName": "CLAS12", "DN": "/OU=LocalUser/CN=gemc", "RawVOName": "/jlab/LocalGroup=clas", "RawCorrectedReportableVOName": "", "RawProjectName": "CLAS12", "RawOIM_Site": "", "OIM_PIName": "Maurizio Ungaro", "OIM_Organization": "Jefferson Lab", "OIM_Department": "Physics", "OIM_FieldOfScience": "Nuclear Physics", "OIM_Facility": "University of Arkansas at Little Rock", "OIM_Site": "UA Little Rock ITS", "OIM_ResourceGroup": "UA-LR-ITS", "OIM_Resource": "UA-LR-ITS-EP", "OIM_ID": "1390", "OIM_FQDN": "ospool-backfill.ualr.edu", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:21:59.125340862Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 2135210.0,
#      'OIM_Site': 'UA Little Rock ITS',
#      'OIM_Department': 'Physics',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 1,
#      'Count': 40,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 3696.0,
#      'checksum': 'd83d8424a73bb69263a8c33f4550812f',
#      'CpuDuration_user': 2131514.0,
#      'ReportableVOName': 'jlab',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'CLAS12',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:scosg2202.jlab.org',
#      'OIM_Facility': 'University of Arkansas at Little Rock',
#      'OIM_FieldOfScience': 'Nuclear Physics',
#      'OIM_ID': '1390',
#      'Host_description': 'UA-LR-ITS-EP',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'CLAS12',
#      'SiteName': 'JLAB',
#      'Njobs': 40.0,
#      'RawVOName': '/jlab/LocalGroup=clas',
#      'OIM_FQDN': 'ospool-backfill.ualr.edu',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '0b4972b82b9f93ede57a5a2069129ca3',
#     '_score': None,
#     '_source': {'CoreHours': 169.96277777777777,
#      'WallDuration': 611866.0,
#      'OIM_ResourceGroup': 'USC-CARC-Artemis',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'USC-CARC-Artemis-Backfill',
#      'OIM_PIName': 'Maurizio Ungaro',
#      'OIM_Organization': 'Jefferson Lab',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=gemc',
#      'VOName': 'jlab',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "USC-CARC-Artemis-Backfill", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "jlab", "ProbeName": "condor-ap:scosg2202.jlab.org", "SiteName": "JLAB", "WallDuration": 611866.0, "CpuDuration_user": 458990.0, "CpuDuration_system": 771.0, "CoreHours": 169.96277777777777, "Njobs": 13.0, "CpuDuration": 459761.0, "Count": 13, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "jlab", "ProjectName": "CLAS12", "DN": "/OU=LocalUser/CN=gemc", "RawVOName": "/jlab/LocalGroup=clas", "RawCorrectedReportableVOName": "", "RawProjectName": "CLAS12", "RawOIM_Site": "", "OIM_PIName": "Maurizio Ungaro", "OIM_Organization": "Jefferson Lab", "OIM_Department": "Physics", "OIM_FieldOfScience": "Nuclear Physics", "OIM_Facility": "University of Southern California", "OIM_Site": "Center for Advanced Research Computing", "OIM_ResourceGroup": "USC-CARC-Artemis", "OIM_Resource": "USC-CARC-Artemis-Backfill", "OIM_ID": "1338", "OIM_FQDN": "artemis-backfill.carc.usc.edu", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:21:59.137472674Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 459761.0,
#      'OIM_Site': 'Center for Advanced Research Computing',
#      'OIM_Department': 'Physics',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 1,
#      'Count': 13,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 771.0,
#      'checksum': '0b4972b82b9f93ede57a5a2069129ca3',
#      'CpuDuration_user': 458990.0,
#      'ReportableVOName': 'jlab',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'CLAS12',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:scosg2202.jlab.org',
#      'OIM_Facility': 'University of Southern California',
#      'OIM_FieldOfScience': 'Nuclear Physics',
#      'OIM_ID': '1338',
#      'Host_description': 'USC-CARC-Artemis-Backfill',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'CLAS12',
#      'SiteName': 'JLAB',
#      'Njobs': 13.0,
#      'RawVOName': '/jlab/LocalGroup=clas',
#      'OIM_FQDN': 'artemis-backfill.carc.usc.edu',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '5b233c523cf555cfe01f4fabdfb46c87',
#     '_score': None,
#     '_source': {'CoreHours': 57.745555555555555,
#      'WallDuration': 207884.0,
#      'OIM_ResourceGroup': 'FANDM-ITS',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'FANDM-ITS-CE1',
#      'OIM_PIName': 'Maurizio Ungaro',
#      'OIM_Organization': 'Jefferson Lab',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=gemc',
#      'VOName': 'jlab',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "FANDM-ITS-CE1", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "jlab", "ProbeName": "condor-ap:scosg2202.jlab.org", "SiteName": "JLAB", "WallDuration": 207884.0, "CpuDuration_user": 81241.0, "CpuDuration_system": 108.0, "CoreHours": 57.745555555555555, "Njobs": 5.0, "CpuDuration": 81349.0, "Count": 5, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "jlab", "ProjectName": "CLAS12", "DN": "/OU=LocalUser/CN=gemc", "RawVOName": "/jlab/LocalGroup=clas", "RawCorrectedReportableVOName": "", "RawProjectName": "CLAS12", "RawOIM_Site": "", "OIM_PIName": "Maurizio Ungaro", "OIM_Organization": "Jefferson Lab", "OIM_Department": "Physics", "OIM_FieldOfScience": "Nuclear Physics", "OIM_Facility": "Franklin and Marshall College", "OIM_Site": "FANDM-ITS", "OIM_ResourceGroup": "FANDM-ITS", "OIM_Resource": "FANDM-ITS-CE1", "OIM_ID": "1296", "OIM_FQDN": "fandm-its-ce1.svc.opensciencegrid.org", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:21:59.137996955Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 81349.0,
#      'OIM_Site': 'FANDM-ITS',
#      'OIM_Department': 'Physics',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 1,
#      'Count': 5,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 108.0,
#      'checksum': '5b233c523cf555cfe01f4fabdfb46c87',
#      'CpuDuration_user': 81241.0,
#      'ReportableVOName': 'jlab',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'CLAS12',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:scosg2202.jlab.org',
#      'OIM_Facility': 'Franklin and Marshall College',
#      'OIM_FieldOfScience': 'Nuclear Physics',
#      'OIM_ID': '1296',
#      'Host_description': 'FANDM-ITS-CE1',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'CLAS12',
#      'SiteName': 'JLAB',
#      'Njobs': 5.0,
#      'RawVOName': '/jlab/LocalGroup=clas',
#      'OIM_FQDN': 'fandm-its-ce1.svc.opensciencegrid.org',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': 'e68e01be83748ed0d1b648a2869873ac',
#     '_score': None,
#     '_source': {'CoreHours': 19.67111111111111,
#      'GPUs': '0',
#      'WallDuration': 70816.0,
#      'CpuDuration_system': 633.0,
#      'checksum': 'e68e01be83748ed0d1b648a2869873ac',
#      'CpuDuration_user': 67194.0,
#      'ReportableVOName': 'jlab',
#      '@version': '1',
#      'type': 'JobUsageRecordSummary',
#      'GPUHours': 0.0,
#      'OIM_PIName': 'Maurizio Ungaro',
#      'OIM_Organization': 'Jefferson Lab',
#      'OIM_Match': 'Host_description-Site',
#      'DN': '/OU=LocalUser/CN=gemc',
#      'VOName': 'jlab',
#      'RawProjectName': 'CLAS12',
#      'CommonName': 'N/A',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "AGLT2", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "jlab", "ProbeName": "condor-ap:scosg2202.jlab.org", "SiteName": "JLAB", "WallDuration": 70816.0, "CpuDuration_user": 67194.0, "CpuDuration_system": 633.0, "CoreHours": 19.67111111111111, "Njobs": 4.0, "CpuDuration": 67827.0, "Count": 4, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "jlab", "ProjectName": "CLAS12", "DN": "/OU=LocalUser/CN=gemc", "RawVOName": "/jlab/LocalGroup=clas", "RawCorrectedReportableVOName": "", "RawProjectName": "CLAS12", "RawOIM_Site": "", "OIM_PIName": "Maurizio Ungaro", "OIM_Organization": "Jefferson Lab", "OIM_Department": "Physics", "OIM_FieldOfScience": "Nuclear Physics", "OIM_Site": "AGLT2", "OIM_Facility": "University of Michigan", "OIM_Match": "Host_description-Site", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      '@received': '2024-10-03T13:21:59.138474832Z',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'CpuDuration': 67827.0,
#      'RawCorrectedReportableVOName': '',
#      'ProbeName': 'condor-ap:scosg2202.jlab.org',
#      'OIM_Department': 'Physics',
#      'OIM_Site': 'AGLT2',
#      'OIM_Facility': 'University of Michigan',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'OIM_FieldOfScience': 'Nuclear Physics',
#      'Processors': 1,
#      'Host_description': 'AGLT2',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'CLAS12',
#      'SiteName': 'JLAB',
#      'Njobs': 4.0,
#      'Count': 4,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'RawVOName': '/jlab/LocalGroup=clas',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '73a4e723393c1744b8e29b30a6f564a8',
#     '_score': None,
#     '_source': {'CoreHours': 20.981944444444444,
#      'GPUs': '0',
#      'WallDuration': 75535.0,
#      'CpuDuration_system': 77.0,
#      'checksum': '73a4e723393c1744b8e29b30a6f564a8',
#      'OIM_ResourceGroup': 'SIUE-CC-production',
#      'CpuDuration_user': 58548.0,
#      'ReportableVOName': 'jlab',
#      '@version': '1',
#      'type': 'JobUsageRecordSummary',
#      'GPUHours': 0.0,
#      'OIM_PIName': 'Maurizio Ungaro',
#      'OIM_Organization': 'Jefferson Lab',
#      'OIM_Match': 'Host_description-ResourceGroup',
#      'DN': '/OU=LocalUser/CN=gemc',
#      'VOName': 'jlab',
#      'RawProjectName': 'CLAS12',
#      'CommonName': 'N/A',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "SIUE-CC-production", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "jlab", "ProbeName": "condor-ap:scosg2202.jlab.org", "SiteName": "JLAB", "WallDuration": 75535.0, "CpuDuration_user": 58548.0, "CpuDuration_system": 77.0, "CoreHours": 20.981944444444444, "Njobs": 4.0, "CpuDuration": 58625.0, "Count": 4, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "jlab", "ProjectName": "CLAS12", "DN": "/OU=LocalUser/CN=gemc", "RawVOName": "/jlab/LocalGroup=clas", "RawCorrectedReportableVOName": "", "RawProjectName": "CLAS12", "RawOIM_Site": "", "OIM_PIName": "Maurizio Ungaro", "OIM_Organization": "Jefferson Lab", "OIM_Department": "Physics", "OIM_FieldOfScience": "Nuclear Physics", "OIM_Site": "SIUE - CC", "OIM_Facility": "Southern Illinois University Edwardsville", "OIM_ResourceGroup": "SIUE-CC-production", "OIM_Match": "Host_description-ResourceGroup", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      '@received': '2024-10-03T13:21:59.138958342Z',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'CpuDuration': 58625.0,
#      'RawCorrectedReportableVOName': '',
#      'ProbeName': 'condor-ap:scosg2202.jlab.org',
#      'OIM_Department': 'Physics',
#      'OIM_Site': 'SIUE - CC',
#      'OIM_Facility': 'Southern Illinois University Edwardsville',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'OIM_FieldOfScience': 'Nuclear Physics',
#      'Processors': 1,
#      'Host_description': 'SIUE-CC-production',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'CLAS12',
#      'SiteName': 'JLAB',
#      'Njobs': 4.0,
#      'Count': 4,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'RawVOName': '/jlab/LocalGroup=clas',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '5682a2c66c948c7ded8226c5c36ae32d',
#     '_score': None,
#     '_source': {'CoreHours': 153.91972222222222,
#      'WallDuration': 554111.0,
#      'OIM_ResourceGroup': 'SYRA-PATH',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'SYRA-PATH-EP',
#      'OIM_PIName': 'Maurizio Ungaro',
#      'OIM_Organization': 'Jefferson Lab',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=gemc',
#      'VOName': 'jlab',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "SYRA-PATH-EP", "Resource_ExitCode": 143, "Grid": "OSG", "ReportableVOName": "jlab", "ProbeName": "condor-ap:scosg2202.jlab.org", "SiteName": "JLAB", "WallDuration": 554111.0, "CpuDuration_user": 529470.0, "CpuDuration_system": 265.0, "CoreHours": 153.91972222222222, "Njobs": 1.0, "CpuDuration": 529735.0, "Count": 1, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "jlab", "ProjectName": "CLAS12", "DN": "/OU=LocalUser/CN=gemc", "RawVOName": "/jlab/LocalGroup=clas", "RawCorrectedReportableVOName": "", "RawProjectName": "CLAS12", "RawOIM_Site": "", "OIM_PIName": "Maurizio Ungaro", "OIM_Organization": "Jefferson Lab", "OIM_Department": "Physics", "OIM_FieldOfScience": "Nuclear Physics", "OIM_Facility": "University of Wisconsin", "OIM_Site": "SYRA-PATH", "OIM_ResourceGroup": "SYRA-PATH", "OIM_Resource": "SYRA-PATH-EP", "OIM_ID": "1385", "OIM_FQDN": "syra-svc-1.facility.path-cc.io", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:21:59.139426897Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 529735.0,
#      'OIM_Site': 'SYRA-PATH',
#      'OIM_Department': 'Physics',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 1,
#      'Count': 1,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 265.0,
#      'checksum': '5682a2c66c948c7ded8226c5c36ae32d',
#      'CpuDuration_user': 529470.0,
#      'ReportableVOName': 'jlab',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'CLAS12',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:scosg2202.jlab.org',
#      'OIM_Facility': 'University of Wisconsin',
#      'OIM_FieldOfScience': 'Nuclear Physics',
#      'OIM_ID': '1385',
#      'Host_description': 'SYRA-PATH-EP',
#      'Resource_ExitCode': 143,
#      'ProjectName': 'CLAS12',
#      'SiteName': 'JLAB',
#      'Njobs': 1.0,
#      'RawVOName': '/jlab/LocalGroup=clas',
#      'OIM_FQDN': 'syra-svc-1.facility.path-cc.io',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '4c60266137ef9da6fd31e153cd1f54bb',
#     '_score': None,
#     '_source': {'CoreHours': 1357.2283333333335,
#      'WallDuration': 4886022.0,
#      'OIM_ResourceGroup': 'SDSC-PRP',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'SDSC-PRP-OSPool-Provisioner',
#      'OIM_PIName': 'John Lajoie',
#      'OIM_Organization': 'Brookhaven National Laboratory',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=eicprod',
#      'VOName': 'jlab',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "SDSC-PRP-OSPool-Provisioner", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "jlab", "ProbeName": "condor-ap:osg-eic.jlab.org", "SiteName": "JLAB", "WallDuration": 4886022.0, "CpuDuration_user": 3563134.0, "CpuDuration_system": 41719.0, "CoreHours": 1357.2283333333335, "Njobs": 424.0, "CpuDuration": 3604853.0, "Count": 424, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "jlab", "ProjectName": "ePIC", "DN": "/OU=LocalUser/CN=eicprod", "RawVOName": "/jlab/LocalGroup=enp", "RawCorrectedReportableVOName": "", "RawProjectName": "ePIC", "RawOIM_Site": "", "OIM_PIName": "John Lajoie", "OIM_Organization": "Brookhaven National Laboratory", "OIM_Department": "Physics", "OIM_FieldOfScience": "Nuclear Physics", "OIM_Facility": "University of California San Diego", "OIM_Site": "San Diego Supercomputer Center", "OIM_ResourceGroup": "SDSC-PRP", "OIM_Resource": "SDSC-PRP-OSPool-Provisioner", "OIM_ID": "1309", "OIM_FQDN": "direct-provisioner.osg-opportunistic.pacificresearchplatform.org", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:21:59.140445743Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 3604853.0,
#      'OIM_Site': 'San Diego Supercomputer Center',
#      'OIM_Department': 'Physics',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 1,
#      'Count': 424,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 41719.0,
#      'checksum': '4c60266137ef9da6fd31e153cd1f54bb',
#      'CpuDuration_user': 3563134.0,
#      'ReportableVOName': 'jlab',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'ePIC',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:osg-eic.jlab.org',
#      'OIM_Facility': 'University of California San Diego',
#      'OIM_FieldOfScience': 'Nuclear Physics',
#      'OIM_ID': '1309',
#      'Host_description': 'SDSC-PRP-OSPool-Provisioner',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'ePIC',
#      'SiteName': 'JLAB',
#      'Njobs': 424.0,
#      'RawVOName': '/jlab/LocalGroup=enp',
#      'OIM_FQDN': 'direct-provisioner.osg-opportunistic.pacificresearchplatform.org',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': 'aa1867828451a562f0674e4d05a62b22',
#     '_score': None,
#     '_source': {'CoreHours': 1565.326388888889,
#      'WallDuration': 5635175.0,
#      'OIM_ResourceGroup': 'Purdue Geddes',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'Purdue-Geddes',
#      'OIM_PIName': 'Yau Wah',
#      'OIM_Organization': 'The University of Chicago',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=jredeker',
#      'VOName': 'osg',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "Purdue-Geddes", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "osg", "ProbeName": "condor-ap:ap23.uc.osg-htc.org", "SiteName": "UChicago_OSGConnect_ap23", "WallDuration": 5635175.0, "CpuDuration_user": 4602950.0, "CpuDuration_system": 27706.0, "CoreHours": 1565.326388888889, "Njobs": 877.0, "CpuDuration": 4630656.0, "Count": 877, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "osg", "ProjectName": "KOTO", "DN": "/OU=LocalUser/CN=jredeker", "RawVOName": "/osg/LocalGroup=collab", "RawCorrectedReportableVOName": "", "RawProjectName": "KOTO", "RawOIM_Site": "", "OIM_PIName": "Yau Wah", "OIM_Organization": "The University of Chicago", "OIM_Department": "Physics", "OIM_FieldOfScience": "High Energy Physics", "OIM_Facility": "Purdue University", "OIM_Site": "Purdue Geddes", "OIM_ResourceGroup": "Purdue Geddes", "OIM_Resource": "Purdue-Geddes", "OIM_ID": "1107", "OIM_FQDN": "geddes.rcac.purdue.edu", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:21:59.405985265Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 4630656.0,
#      'OIM_Site': 'Purdue Geddes',
#      'OIM_Department': 'Physics',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 1,
#      'Count': 877,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 27706.0,
#      'checksum': 'aa1867828451a562f0674e4d05a62b22',
#      'CpuDuration_user': 4602950.0,
#      'ReportableVOName': 'osg',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'KOTO',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:ap23.uc.osg-htc.org',
#      'OIM_Facility': 'Purdue University',
#      'OIM_FieldOfScience': 'High Energy Physics',
#      'OIM_ID': '1107',
#      'Host_description': 'Purdue-Geddes',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'KOTO',
#      'SiteName': 'UChicago_OSGConnect_ap23',
#      'Njobs': 877.0,
#      'RawVOName': '/osg/LocalGroup=collab',
#      'OIM_FQDN': 'geddes.rcac.purdue.edu',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': 'cde5a34159fc35f82439c0027d1e7e25',
#     '_score': None,
#     '_source': {'CoreHours': 3.261111111111111,
#      'WallDuration': 11740.0,
#      'OIM_ResourceGroup': 'USC-CARC-Artemis',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'USC-CARC-Artemis-Backfill',
#      'OIM_PIName': 'Yau Wah',
#      'OIM_Organization': 'The University of Chicago',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=jredeker',
#      'VOName': 'osg',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "USC-CARC-Artemis-Backfill", "Resource_ExitCode": 135, "Grid": "OSG", "ReportableVOName": "osg", "ProbeName": "condor-ap:ap23.uc.osg-htc.org", "SiteName": "UChicago_OSGConnect_ap23", "WallDuration": 11740.0, "CpuDuration_user": 10415.0, "CpuDuration_system": 36.0, "CoreHours": 3.261111111111111, "Njobs": 4.0, "CpuDuration": 10451.0, "Count": 4, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "osg", "ProjectName": "KOTO", "DN": "/OU=LocalUser/CN=jredeker", "RawVOName": "/osg/LocalGroup=collab", "RawCorrectedReportableVOName": "", "RawProjectName": "KOTO", "RawOIM_Site": "", "OIM_PIName": "Yau Wah", "OIM_Organization": "The University of Chicago", "OIM_Department": "Physics", "OIM_FieldOfScience": "High Energy Physics", "OIM_Facility": "University of Southern California", "OIM_Site": "Center for Advanced Research Computing", "OIM_ResourceGroup": "USC-CARC-Artemis", "OIM_Resource": "USC-CARC-Artemis-Backfill", "OIM_ID": "1338", "OIM_FQDN": "artemis-backfill.carc.usc.edu", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:21:59.474767982Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 10451.0,
#      'OIM_Site': 'Center for Advanced Research Computing',
#      'OIM_Department': 'Physics',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 1,
#      'Count': 4,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 36.0,
#      'checksum': 'cde5a34159fc35f82439c0027d1e7e25',
#      'CpuDuration_user': 10415.0,
#      'ReportableVOName': 'osg',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'KOTO',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:ap23.uc.osg-htc.org',
#      'OIM_Facility': 'University of Southern California',
#      'OIM_FieldOfScience': 'High Energy Physics',
#      'OIM_ID': '1338',
#      'Host_description': 'USC-CARC-Artemis-Backfill',
#      'Resource_ExitCode': 135,
#      'ProjectName': 'KOTO',
#      'SiteName': 'UChicago_OSGConnect_ap23',
#      'Njobs': 4.0,
#      'RawVOName': '/osg/LocalGroup=collab',
#      'OIM_FQDN': 'artemis-backfill.carc.usc.edu',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '91de520100c1247dda73788b9d64fc89',
#     '_score': None,
#     '_source': {'CoreHours': 2389.0866666666666,
#      'WallDuration': 4300356.0,
#      'OIM_ResourceGroup': 'UC-Denver',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'UC-Denver-CE1',
#      'OIM_PIName': 'Chi-Kwan Chan',
#      'OIM_Organization': 'University of Arizona',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=avjoshi2',
#      'VOName': 'osg',
#      'event': {'original': '{"Processors": 2, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "UC-Denver-CE1", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "osg", "ProbeName": "condor-ap:ap23.uc.osg-htc.org", "SiteName": "UChicago_OSGConnect_ap23", "WallDuration": 4300356.0, "CpuDuration_user": 4676375.0, "CpuDuration_system": 3391.0, "CoreHours": 2389.0866666666666, "Njobs": 1994.0, "CpuDuration": 4679766.0, "Count": 1994, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "osg", "ProjectName": "eht", "DN": "/OU=LocalUser/CN=avjoshi2", "RawVOName": "/osg/LocalGroup=collab", "RawCorrectedReportableVOName": "", "RawProjectName": "eht", "RawOIM_Site": "", "OIM_PIName": "Chi-Kwan Chan", "OIM_Organization": "University of Arizona", "OIM_Department": "Astronomy", "OIM_FieldOfScience": "Astronomy", "OIM_Facility": "University of Colorado Denver", "OIM_Site": "University of Colorado Denver", "OIM_ResourceGroup": "UC-Denver", "OIM_Resource": "UC-Denver-CE1", "OIM_ID": "1306", "OIM_FQDN": "uc-denver-ce1.svc.opensciencegrid.org", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Astronomy", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:21:59.476075726Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 4679766.0,
#      'OIM_Site': 'University of Colorado Denver',
#      'OIM_Department': 'Astronomy',
#      'OIM_NSFFieldOfScience': 'Astronomy',
#      'Processors': 2,
#      'Count': 1994,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 3391.0,
#      'checksum': '91de520100c1247dda73788b9d64fc89',
#      'CpuDuration_user': 4676375.0,
#      'ReportableVOName': 'osg',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'eht',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:ap23.uc.osg-htc.org',
#      'OIM_Facility': 'University of Colorado Denver',
#      'OIM_FieldOfScience': 'Astronomy',
#      'OIM_ID': '1306',
#      'Host_description': 'UC-Denver-CE1',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'eht',
#      'SiteName': 'UChicago_OSGConnect_ap23',
#      'Njobs': 1994.0,
#      'RawVOName': '/osg/LocalGroup=collab',
#      'OIM_FQDN': 'uc-denver-ce1.svc.opensciencegrid.org',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '97646ecd1fd52a4f68d1cee0cedfc513',
#     '_score': None,
#     '_source': {'CoreHours': 88.81388888888888,
#      'WallDuration': 319730.0,
#      'OIM_ResourceGroup': 'UWEC-BOSE',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'UWEC-BOSE-CE1',
#      'OIM_PIName': 'Yau Wah',
#      'OIM_Organization': 'The University of Chicago',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=jredeker',
#      'VOName': 'osg',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "UWEC-BOSE-CE1", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "osg", "ProbeName": "condor-ap:ap23.uc.osg-htc.org", "SiteName": "UChicago_OSGConnect_ap23", "WallDuration": 319730.0, "CpuDuration_user": 262143.0, "CpuDuration_system": 403.0, "CoreHours": 88.81388888888888, "Njobs": 77.0, "CpuDuration": 262546.0, "Count": 77, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "osg", "ProjectName": "KOTO", "DN": "/OU=LocalUser/CN=jredeker", "RawVOName": "/osg/LocalGroup=collab", "RawCorrectedReportableVOName": "", "RawProjectName": "KOTO", "RawOIM_Site": "", "OIM_PIName": "Yau Wah", "OIM_Organization": "The University of Chicago", "OIM_Department": "Physics", "OIM_FieldOfScience": "High Energy Physics", "OIM_Facility": "University of Wisconsin\\u2013Eau Claire", "OIM_Site": "UW-Eau Claire LTS", "OIM_ResourceGroup": "UWEC-BOSE", "OIM_Resource": "UWEC-BOSE-CE1", "OIM_ID": "1669247749", "OIM_FQDN": "uwec-bose-ce1.svc.opensciencegrid.org", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:21:59.474926269Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 262546.0,
#      'OIM_Site': 'UW-Eau Claire LTS',
#      'OIM_Department': 'Physics',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 1,
#      'Count': 77,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 403.0,
#      'checksum': '97646ecd1fd52a4f68d1cee0cedfc513',
#      'CpuDuration_user': 262143.0,
#      'ReportableVOName': 'osg',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'KOTO',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:ap23.uc.osg-htc.org',
#      'OIM_Facility': 'University of Wisconsin–Eau Claire',
#      'OIM_FieldOfScience': 'High Energy Physics',
#      'OIM_ID': '1669247749',
#      'Host_description': 'UWEC-BOSE-CE1',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'KOTO',
#      'SiteName': 'UChicago_OSGConnect_ap23',
#      'Njobs': 77.0,
#      'RawVOName': '/osg/LocalGroup=collab',
#      'OIM_FQDN': 'uwec-bose-ce1.svc.opensciencegrid.org',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '2d9f5a94b1714cc97c425465b66731c9',
#     '_score': None,
#     '_source': {'CoreHours': 2.8005555555555555,
#      'WallDuration': 10082.0,
#      'OIM_ResourceGroup': 'WISC-PATH',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'WISC-PATH-EP',
#      'OIM_PIName': "Richard O'Shaughnessy",
#      'OIM_Organization': 'Rochester Institute of Technology',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=sarosboro',
#      'VOName': 'osg',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "WISC-PATH-EP", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "osg", "ProbeName": "condor-ap:ap20.uc.osg-htc.org", "SiteName": "UChicago_OSGConnect_ap20", "WallDuration": 10082.0, "CpuDuration_user": 7964.0, "CpuDuration_system": 984.0, "CoreHours": 2.8005555555555555, "Njobs": 74.0, "CpuDuration": 8948.0, "Count": 74, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "osg", "ProjectName": "CompBinFormMod", "DN": "/OU=LocalUser/CN=sarosboro", "RawVOName": "/osg/LocalGroup=osg", "RawCorrectedReportableVOName": "", "RawProjectName": "CompBinFormMod", "RawOIM_Site": "", "OIM_PIName": "Richard O\'Shaughnessy", "OIM_Organization": "Rochester Institute of Technology", "OIM_Department": "School of Mathematical Sciences", "OIM_FieldOfScience": "Astronomy and Astrophysics", "OIM_Facility": "University of Wisconsin", "OIM_Site": "WISC-PATH", "OIM_ResourceGroup": "WISC-PATH", "OIM_Resource": "WISC-PATH-EP", "OIM_ID": "1368", "OIM_FQDN": "wisc-svc-1.facility.path-cc.io", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Astronomy", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:22:00.433174990Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 8948.0,
#      'OIM_Site': 'WISC-PATH',
#      'OIM_Department': 'School of Mathematical Sciences',
#      'OIM_NSFFieldOfScience': 'Astronomy',
#      'Processors': 1,
#      'Count': 74,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 984.0,
#      'checksum': '2d9f5a94b1714cc97c425465b66731c9',
#      'CpuDuration_user': 7964.0,
#      'ReportableVOName': 'osg',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'CompBinFormMod',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:ap20.uc.osg-htc.org',
#      'OIM_Facility': 'University of Wisconsin',
#      'OIM_FieldOfScience': 'Astronomy and Astrophysics',
#      'OIM_ID': '1368',
#      'Host_description': 'WISC-PATH-EP',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'CompBinFormMod',
#      'SiteName': 'UChicago_OSGConnect_ap20',
#      'Njobs': 74.0,
#      'RawVOName': '/osg/LocalGroup=osg',
#      'OIM_FQDN': 'wisc-svc-1.facility.path-cc.io',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '4a9dfd33f918afced2c590948ea76d09',
#     '_score': None,
#     '_source': {'CoreHours': 1.4558333333333333,
#      'WallDuration': 5241.0,
#      'OIM_ResourceGroup': 'GP-ARGO-uark',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'GP-ARGO-uark-backfill',
#      'OIM_PIName': "Richard O'Shaughnessy",
#      'OIM_Organization': 'Rochester Institute of Technology',
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=sarosboro',
#      'VOName': 'osg',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "GP-ARGO-uark-backfill", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "osg", "ProbeName": "condor-ap:ap20.uc.osg-htc.org", "SiteName": "UChicago_OSGConnect_ap20", "WallDuration": 5241.0, "CpuDuration_user": 3069.0, "CpuDuration_system": 252.0, "CoreHours": 1.4558333333333333, "Njobs": 28.0, "CpuDuration": 3321.0, "Count": 28, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "osg", "ProjectName": "CompBinFormMod", "DN": "/OU=LocalUser/CN=sarosboro", "RawVOName": "/osg/LocalGroup=osg", "RawCorrectedReportableVOName": "", "RawProjectName": "CompBinFormMod", "RawOIM_Site": "", "OIM_PIName": "Richard O\'Shaughnessy", "OIM_Organization": "Rochester Institute of Technology", "OIM_Department": "School of Mathematical Sciences", "OIM_FieldOfScience": "Astronomy and Astrophysics", "OIM_Facility": "Great Plains Network", "OIM_Site": "University of Arkansas", "OIM_ResourceGroup": "GP-ARGO-uark", "OIM_Resource": "GP-ARGO-uark-backfill", "OIM_ID": "1333", "OIM_FQDN": "uark.gp-argo.greatplains.net", "OIM_Match": "Host_description-Resource", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Astronomy", "GPUHours": 0.0}'},
#      'CommonName': 'N/A',
#      '@received': '2024-10-03T13:22:00.435048310Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 3321.0,
#      'OIM_Site': 'University of Arkansas',
#      'OIM_Department': 'School of Mathematical Sciences',
#      'OIM_NSFFieldOfScience': 'Astronomy',
#      'Processors': 1,
#      'Count': 28,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 252.0,
#      'checksum': '4a9dfd33f918afced2c590948ea76d09',
#      'CpuDuration_user': 3069.0,
#      'ReportableVOName': 'osg',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'CompBinFormMod',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'ProbeName': 'condor-ap:ap20.uc.osg-htc.org',
#      'OIM_Facility': 'Great Plains Network',
#      'OIM_FieldOfScience': 'Astronomy and Astrophysics',
#      'OIM_ID': '1333',
#      'Host_description': 'GP-ARGO-uark-backfill',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'CompBinFormMod',
#      'SiteName': 'UChicago_OSGConnect_ap20',
#      'Njobs': 28.0,
#      'RawVOName': '/osg/LocalGroup=osg',
#      'OIM_FQDN': 'uark.gp-argo.greatplains.net',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': 'ed7b2434b7fc1963e84d3d6abefabf6a',
#     '_score': None,
#     '_source': {'CoreHours': 0.0025,
#      'GPUs': '0',
#      'WallDuration': 9.0,
#      'CpuDuration_system': 0.0,
#      'checksum': 'ed7b2434b7fc1963e84d3d6abefabf6a',
#      'OIM_ResourceGroup': 'GPGRID',
#      'CpuDuration_user': 0.0,
#      'ReportableVOName': 'osg',
#      '@version': '1',
#      'type': 'JobUsageRecordSummary',
#      'GPUHours': 0.0,
#      'OIM_PIName': 'Oana Carja',
#      'OIM_Organization': 'University of Pennsylvania',
#      'OIM_Match': 'Host_description-ResourceGroup',
#      'DN': '/OU=LocalUser/CN=monica_wannnn',
#      'VOName': 'osg',
#      'RawProjectName': 'EvolSims',
#      'CommonName': 'N/A',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Payload", "CommonName": "N/A", "Host_description": "GPGrid", "Resource_ExitCode": 1, "Grid": "OSG", "ReportableVOName": "osg", "ProbeName": "condor-ap:ap21.uc.osg-htc.org", "SiteName": "UChicago_OSGConnect_ap21", "WallDuration": 9.0, "CpuDuration_user": 0.0, "CpuDuration_system": 0.0, "CoreHours": 0.0025, "Njobs": 1.0, "CpuDuration": 0.0, "Count": 1, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "osg", "ProjectName": "EvolSims", "DN": "/OU=LocalUser/CN=monica_wannnn", "RawVOName": "/osg/LocalGroup=osg", "RawCorrectedReportableVOName": "", "RawProjectName": "EvolSims", "RawOIM_Site": "", "OIM_PIName": "Oana Carja", "OIM_Organization": "University of Pennsylvania", "OIM_Department": "Biology", "OIM_FieldOfScience": "Biological Sciences", "OIM_Site": "FermiGrid", "OIM_Facility": "Fermi National Accelerator Laboratory", "OIM_ResourceGroup": "GPGRID", "OIM_Match": "Host_description-ResourceGroup", "OIM_NSFFieldOfScience": "Biological Sciences", "GPUHours": 0.0}'},
#      '@received': '2024-10-03T13:22:00.622017595Z',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Payload',
#      'CpuDuration': 0.0,
#      'RawCorrectedReportableVOName': '',
#      'ProbeName': 'condor-ap:ap21.uc.osg-htc.org',
#      'OIM_Department': 'Biology',
#      'OIM_Site': 'FermiGrid',
#      'OIM_Facility': 'Fermi National Accelerator Laboratory',
#      'OIM_NSFFieldOfScience': 'Biological Sciences',
#      'OIM_FieldOfScience': 'Biological Sciences',
#      'Processors': 1,
#      'Host_description': 'GPGrid',
#      'Resource_ExitCode': 1,
#      'ProjectName': 'EvolSims',
#      'SiteName': 'UChicago_OSGConnect_ap21',
#      'Njobs': 1.0,
#      'Count': 1,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'RawVOName': '/osg/LocalGroup=osg',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': 'f1eae1fb3039211cdf5f51e733c2d96c',
#     '_score': None,
#     '_source': {'CoreHours': 4.05,
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '1',
#      'WallDuration': 972.0,
#      'CpuDuration_system': 0.0,
#      'checksum': 'f1eae1fb3039211cdf5f51e733c2d96c',
#      'OIM_ResourceGroup': 'LSU-Deep_Bayou',
#      'CpuDuration_user': 0.0,
#      'ReportableVOName': 'osg',
#      '@version': '1',
#      'OIM_Resource': 'LSU-DB-CE1',
#      'type': 'JobUsageRecordSummary',
#      'GPUHours': 0.27,
#      'OIM_Match': 'Host_description-Resource',
#      'DN': '/OU=LocalUser/CN=elias2800',
#      'VOName': 'osg',
#      'RawProjectName': 'Harvard_Aganj',
#      'CommonName': 'N/A',
# ...
#      'Processors': 1,
#      'OIM_WLCGAccountingName': 'US-MWT2',
#      'Count': 2455,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'DEDICATED',
#      'GPUs': '0',
#      'CpuDuration_system': 5506099.0,
#      'checksum': '1eddfb470669dc14d68d51a5bf368249',
#      'CpuDuration_user': 112668115.0,
#      'ReportableVOName': 'https://atlas-auth.web.cern.ch/',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'N/A',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Batch',
#      'ProbeName': 'htcondor-ce:uct2-gk02.mwt2.org',
#      'OIM_WLCGAPELNormalizedCpuDuration': 1667438159.54,
#      'OIM_Facility': 'University of Chicago',
#      'OIM_FieldOfScience': 'High Energy Physics',
#      'OIM_ID': '1299',
#      'Host_description': 'N/A',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'atlas',
#      'SiteName': 'MWT2_CE_UC',
#      'Njobs': 2455.0,
#      'RawVOName': 'https://atlas-auth.web.cern.ch/',
#      'OIM_FQDN': 'uct2-gk02.mwt2.org',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '4ffe4af260026f1d760529d0b6dbcdbd',
#     '_score': None,
#     '_source': {'OIM_WLCGAPELNormalFactor': 14.11,
#      'CoreHours': 69850.91111111111,
#      'WallDuration': 31432910.0,
#      'OIM_ResourceGroup': 'MWT2',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'MWT2_CE_UIUC',
#      'OIM_Match': 'ProbeName-FQDN',
#      'DN': '/DC=ch/DC=cern/OU=Organic Units/OU=Users/CN=atlpilo1/CN=614260/CN=Robot: ATLAS Pilot1',
#      'VOName': 'atlas',
#      'OIM_WLCGAPELNormalizedWallDuration': 3548146880.7999997,
#      'CommonName': 'N/A',
#      'event': {'original': '{"Processors": 8, "GPUs": "0", "ResourceType": "Batch", "CommonName": "N/A", "Host_description": "N/A", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "https://atlas-auth.web.cern.ch/", "ProbeName": "htcondor-ce:uiuc-gk.mwt2.org", "SiteName": "MWT2_CE_UIUC", "WallDuration": 31432910.0, "CpuDuration_user": 175119281.0, "CpuDuration_system": 4695482.0, "CoreHours": 69850.91111111111, "Njobs": 789.0, "CpuDuration": 179814763.0, "Count": 789, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "atlas", "ProjectName": "atlas", "DN": "/DC=ch/DC=cern/OU=Organic Units/OU=Users/CN=atlpilo1/CN=614260/CN=Robot: ATLAS Pilot1", "RawVOName": "https://atlas-auth.web.cern.ch/", "RawCorrectedReportableVOName": "", "RawProjectName": "N/A", "RawOIM_Site": "", "OIM_FieldOfScience": "High Energy Physics", "OIM_Facility": "University of Chicago", "OIM_Site": "MWT2 ATLAS UC", "OIM_ResourceGroup": "MWT2", "OIM_Resource": "MWT2_CE_UIUC", "OIM_ID": "490", "OIM_FQDN": "uiuc-gk.mwt2.org", "OIM_WLCGAccountingName": "US-MWT2", "OIM_WLCGAPELNormalFactor": 14.11, "OIM_Match": "ProbeName-FQDN", "OIM_UsageModel": "DEDICATED", "OIM_NSFFieldOfScience": "Physics", "OIM_WLCGAPELNormalizedWallDuration": 3548146880.7999997, "OIM_WLCGAPELNormalizedCpuDuration": 2537186305.93, "GPUHours": 0.0}'},
#      '@received': '2024-10-03T13:22:03.496284347Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 179814763.0,
#      'OIM_Site': 'MWT2 ATLAS UC',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 8,
#      'OIM_WLCGAccountingName': 'US-MWT2',
#      'Count': 789,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'DEDICATED',
#      'GPUs': '0',
#      'CpuDuration_system': 4695482.0,
#      'checksum': '4ffe4af260026f1d760529d0b6dbcdbd',
#      'CpuDuration_user': 175119281.0,
#      'ReportableVOName': 'https://atlas-auth.web.cern.ch/',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'N/A',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Batch',
#      'ProbeName': 'htcondor-ce:uiuc-gk.mwt2.org',
#      'OIM_WLCGAPELNormalizedCpuDuration': 2537186305.93,
#      'OIM_Facility': 'University of Chicago',
#      'OIM_FieldOfScience': 'High Energy Physics',
#      'OIM_ID': '490',
#      'Host_description': 'N/A',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'atlas',
#      'SiteName': 'MWT2_CE_UIUC',
#      'Njobs': 789.0,
#      'RawVOName': 'https://atlas-auth.web.cern.ch/',
#      'OIM_FQDN': 'uiuc-gk.mwt2.org',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '6fcf64510c7cd58f503cd40fb976f1b0',
#     '_score': None,
#     '_source': {'OIM_WLCGAPELNormalFactor': 14.11,
#      'CoreHours': 0.0044444444444444444,
#      'WallDuration': 2.0,
#      'OIM_ResourceGroup': 'MWT2',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'MWT2_CE_UC2',
#      'OIM_Match': 'ProbeName-FQDN',
#      'DN': '5c5d2a4d-9177-3efa-912f-1b4e5c9fb660',
#      'VOName': 'atlas',
#      'OIM_WLCGAPELNormalizedWallDuration': 225.76,
#      'CommonName': 'N/A',
#      'event': {'original': '{"Processors": 8, "GPUs": "0", "ResourceType": "Batch", "CommonName": "N/A", "Host_description": "N/A", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "https://atlas-auth.web.cern.ch/", "ProbeName": "htcondor-ce:uct2-gk02.mwt2.org", "SiteName": "MWT2_CE_UC", "WallDuration": 2.0, "CpuDuration_user": 0.0, "CpuDuration_system": 0.0, "CoreHours": 0.0044444444444444444, "Njobs": 6.0, "CpuDuration": 0.0, "Count": 6, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "atlas", "ProjectName": "atlas", "DN": "5c5d2a4d-9177-3efa-912f-1b4e5c9fb660", "RawVOName": "https://atlas-auth.web.cern.ch/", "RawCorrectedReportableVOName": "", "RawProjectName": "N/A", "RawOIM_Site": "", "OIM_FieldOfScience": "High Energy Physics", "OIM_Facility": "University of Chicago", "OIM_Site": "MWT2 ATLAS UC", "OIM_ResourceGroup": "MWT2", "OIM_Resource": "MWT2_CE_UC2", "OIM_ID": "1299", "OIM_FQDN": "uct2-gk02.mwt2.org", "OIM_WLCGAccountingName": "US-MWT2", "OIM_WLCGAPELNormalFactor": 14.11, "OIM_Match": "ProbeName-FQDN", "OIM_UsageModel": "DEDICATED", "OIM_NSFFieldOfScience": "Physics", "OIM_WLCGAPELNormalizedWallDuration": 225.76, "OIM_WLCGAPELNormalizedCpuDuration": 0.0, "GPUHours": 0.0}'},
#      '@received': '2024-10-03T13:22:03.784898635Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 0.0,
#      'OIM_Site': 'MWT2 ATLAS UC',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 8,
#      'OIM_WLCGAccountingName': 'US-MWT2',
#      'Count': 6,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'DEDICATED',
#      'GPUs': '0',
#      'CpuDuration_system': 0.0,
#      'checksum': '6fcf64510c7cd58f503cd40fb976f1b0',
#      'CpuDuration_user': 0.0,
#      'ReportableVOName': 'https://atlas-auth.web.cern.ch/',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'N/A',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Batch',
#      'ProbeName': 'htcondor-ce:uct2-gk02.mwt2.org',
#      'OIM_WLCGAPELNormalizedCpuDuration': 0.0,
#      'OIM_Facility': 'University of Chicago',
#      'OIM_FieldOfScience': 'High Energy Physics',
#      'OIM_ID': '1299',
#      'Host_description': 'N/A',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'atlas',
#      'SiteName': 'MWT2_CE_UC',
#      'Njobs': 6.0,
#      'RawVOName': 'https://atlas-auth.web.cern.ch/',
#      'OIM_FQDN': 'uct2-gk02.mwt2.org',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': '92e194556b271c269527f866f6ae67ac',
#     '_score': None,
#     '_source': {'OIM_WLCGAPELNormalFactor': 14.11,
#      'CoreHours': 22.715555555555557,
#      'WallDuration': 10222.0,
#      'OIM_ResourceGroup': 'MWT2',
#      'type': 'JobUsageRecordSummary',
#      'OIM_Resource': 'MWT2_CE_IU',
#      'OIM_PIName': 'Thomas Robert Junk',
#      'OIM_Organization': 'DUNE',
#      'OIM_Match': 'ProbeName-FQDN',
#      'DN': '/DC=org/DC=incommon/C=US/ST=Illinois/O=Fermi Research Alliance/CN=pilot-gpfrontend01.fnal.gov',
#      'VOName': 'dune',
#      'OIM_WLCGAPELNormalizedWallDuration': 1153859.3599999999,
#      'CommonName': 'N/A',
#      'event': {'original': '{"Processors": 8, "GPUs": "0", "ResourceType": "Batch", "CommonName": "N/A", "Host_description": "N/A", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "https://cilogon.org/dune", "ProbeName": "htcondor-ce:iut2-gk.mwt2.org", "SiteName": "MWT2_CE_IU", "WallDuration": 10222.0, "CpuDuration_user": 3759.0, "CpuDuration_system": 894.0, "CoreHours": 22.715555555555557, "Njobs": 6.0, "CpuDuration": 4653.0, "Count": 6, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "dune", "ProjectName": "dune", "DN": "/DC=org/DC=incommon/C=US/ST=Illinois/O=Fermi Research Alliance/CN=pilot-gpfrontend01.fnal.gov", "RawVOName": "https://cilogon.org/dune", "RawCorrectedReportableVOName": "", "RawProjectName": "N/A", "RawOIM_Site": "", "OIM_FieldOfScience": "High Energy Physics", "OIM_PIName": "Thomas Robert Junk", "OIM_Organization": "DUNE", "OIM_Department": "N/A", "OIM_Facility": "University of Chicago", "OIM_Site": "MWT2 ATLAS UC", "OIM_ResourceGroup": "MWT2", "OIM_Resource": "MWT2_CE_IU", "OIM_ID": "470", "OIM_FQDN": "iut2-gk.mwt2.org", "OIM_WLCGAccountingName": "US-MWT2", "OIM_WLCGAPELNormalFactor": 14.11, "OIM_Match": "ProbeName-FQDN", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "OIM_WLCGAPELNormalizedWallDuration": 1153859.3599999999, "OIM_WLCGAPELNormalizedCpuDuration": 65653.83, "GPUHours": 0.0}'},
#      '@received': '2024-10-03T13:22:03.799754529Z',
#      'RawCorrectedReportableVOName': '',
#      'CpuDuration': 4653.0,
#      'OIM_Site': 'MWT2 ATLAS UC',
#      'OIM_Department': 'N/A',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'Processors': 8,
#      'OIM_WLCGAccountingName': 'US-MWT2',
#      'Count': 6,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'CpuDuration_system': 894.0,
#      'checksum': '92e194556b271c269527f866f6ae67ac',
#      'CpuDuration_user': 3759.0,
#      'ReportableVOName': 'https://cilogon.org/dune',
#      '@version': '1',
#      'GPUHours': 0.0,
#      'RawProjectName': 'N/A',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Batch',
#      'ProbeName': 'htcondor-ce:iut2-gk.mwt2.org',
#      'OIM_WLCGAPELNormalizedCpuDuration': 65653.83,
#      'OIM_Facility': 'University of Chicago',
#      'OIM_FieldOfScience': 'High Energy Physics',
#      'OIM_ID': '470',
#      'Host_description': 'N/A',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'dune',
#      'SiteName': 'MWT2_CE_IU',
#      'Njobs': 6.0,
#      'RawVOName': 'https://cilogon.org/dune',
#      'OIM_FQDN': 'iut2-gk.mwt2.org',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': 'ab7b0b4b6b5855b3331a8f37f6c60c3c',
#     '_score': None,
#     '_source': {'CoreHours': 2.876666666666667,
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'WallDuration': 10356.0,
#      'CpuDuration_system': 181.0,
#      'checksum': 'ab7b0b4b6b5855b3331a8f37f6c60c3c',
#      'OIM_ResourceGroup': 'GLOW',
#      'CpuDuration_user': 226.0,
#      'ReportableVOName': 'https://cilogon.org/dune',
#      '@version': '1',
#      'OIM_Resource': 'GLOW-OSG',
#      'type': 'JobUsageRecordSummary',
#      'GPUHours': 0.0,
#      'OIM_Match': 'ProbeName-FQDN',
#      'DN': '/DC=org/DC=incommon/C=US/ST=Illinois/O=Fermi Research Alliance/CN=pilot-gpfrontend01.fnal.gov',
#      'VOName': 'dune',
#      'RawProjectName': 'HEP',
#      'CommonName': 'N/A',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Batch", "CommonName": "N/A", "Host_description": "N/A", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "https://cilogon.org/dune", "ProbeName": "htcondor-ce:osggrid01.hep.wisc.edu", "SiteName": "GLOW-OSG", "WallDuration": 10356.0, "CpuDuration_user": 226.0, "CpuDuration_system": 181.0, "CoreHours": 2.876666666666667, "Njobs": 7.0, "CpuDuration": 407.0, "Count": 7, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "dune", "ProjectName": "HEP", "DN": "/DC=org/DC=incommon/C=US/ST=Illinois/O=Fermi Research Alliance/CN=pilot-gpfrontend01.fnal.gov", "RawVOName": "https://cilogon.org/dune", "RawCorrectedReportableVOName": "", "RawProjectName": "HEP", "RawOIM_Site": "", "OIM_FieldOfScience": "High Energy Physics", "OIM_Facility": "University of Wisconsin", "OIM_Site": "GLOW", "OIM_ResourceGroup": "GLOW", "OIM_Resource": "GLOW-OSG", "OIM_ID": "361", "OIM_FQDN": "osggrid01.hep.wisc.edu", "OIM_Match": "ProbeName-FQDN", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Physics", "GPUHours": 0.0}'},
#      '@received': '2024-10-03T13:22:03.800972615Z',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Batch',
#      'CpuDuration': 407.0,
#      'RawCorrectedReportableVOName': '',
#      'ProbeName': 'htcondor-ce:osggrid01.hep.wisc.edu',
#      'OIM_Site': 'GLOW',
#      'OIM_Facility': 'University of Wisconsin',
#      'OIM_NSFFieldOfScience': 'Physics',
#      'OIM_FieldOfScience': 'High Energy Physics',
#      'OIM_ID': '361',
#      'Processors': 1,
#      'Host_description': 'N/A',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'HEP',
#      'SiteName': 'GLOW-OSG',
#      'Njobs': 7.0,
#      'Count': 7,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'RawVOName': 'https://cilogon.org/dune',
#      'OIM_FQDN': 'osggrid01.hep.wisc.edu',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]},
#    {'_index': 'gracc.osg.summary4-2024',
#     '_id': 'f879faee75e40372111ac5c2162156af',
#     '_score': None,
#     '_source': {'CoreHours': 826.3283333333334,
#      'OIM_UsageModel': 'OPPORTUNISTIC',
#      'GPUs': '0',
#      'WallDuration': 2974782.0,
#      'CpuDuration_system': 48835.0,
#      'checksum': 'f879faee75e40372111ac5c2162156af',
#      'OIM_ResourceGroup': 'GLOW',
#      'CpuDuration_user': 1171006.0,
#      'ReportableVOName': 'https://cilogon.org/fermilab',
#      '@version': '1',
#      'OIM_Resource': 'GLOW-OSG',
#      'type': 'JobUsageRecordSummary',
#      'GPUHours': 0.0,
#      'OIM_Match': 'ProbeName-FQDN',
#      'DN': '/DC=org/DC=incommon/C=US/ST=Illinois/O=Fermi Research Alliance/CN=pilot-gpfrontend01.fnal.gov',
#      'VOName': 'fermilab',
#      'RawProjectName': 'HEP',
#      'CommonName': 'N/A',
#      'event': {'original': '{"Processors": 1, "GPUs": "0", "ResourceType": "Batch", "CommonName": "N/A", "Host_description": "N/A", "Resource_ExitCode": 0, "Grid": "OSG", "ReportableVOName": "https://cilogon.org/fermilab", "ProbeName": "htcondor-ce:osggrid01.hep.wisc.edu", "SiteName": "GLOW-OSG", "WallDuration": 2974782.0, "CpuDuration_user": 1171006.0, "CpuDuration_system": 48835.0, "CoreHours": 826.3283333333334, "Njobs": 1198.0, "CpuDuration": 1219841.0, "Count": 1198, "EndTime": "2024-10-03T00:00:00.000Z", "VOName": "fermilab", "ProjectName": "HEP", "DN": "/DC=org/DC=incommon/C=US/ST=Illinois/O=Fermi Research Alliance/CN=pilot-gpfrontend01.fnal.gov", "RawVOName": "https://cilogon.org/fermilab", "RawCorrectedReportableVOName": "", "RawProjectName": "HEP", "RawOIM_Site": "", "OIM_FieldOfScience": "National Laboratory", "OIM_Facility": "University of Wisconsin", "OIM_Site": "GLOW", "OIM_ResourceGroup": "GLOW", "OIM_Resource": "GLOW-OSG", "OIM_ID": "361", "OIM_FQDN": "osggrid01.hep.wisc.edu", "OIM_Match": "ProbeName-FQDN", "OIM_UsageModel": "OPPORTUNISTIC", "OIM_NSFFieldOfScience": "Integrative Activities", "GPUHours": 0.0}'},
#      '@received': '2024-10-03T13:22:03.869736599Z',
#      '@timestamp': '2024-10-03T00:00:00.000Z',
#      'ResourceType': 'Batch',
#      'CpuDuration': 1219841.0,
#      'RawCorrectedReportableVOName': '',
#      'ProbeName': 'htcondor-ce:osggrid01.hep.wisc.edu',
#      'OIM_Site': 'GLOW',
#      'OIM_Facility': 'University of Wisconsin',
#      'OIM_NSFFieldOfScience': 'Integrative Activities',
#      'OIM_FieldOfScience': 'National Laboratory',
#      'OIM_ID': '361',
#      'Processors': 1,
#      'Host_description': 'N/A',
#      'Resource_ExitCode': 0,
#      'ProjectName': 'HEP',
#      'SiteName': 'GLOW-OSG',
#      'Njobs': 1198.0,
#      'Count': 1198,
#      'Grid': 'OSG',
#      'EndTime': '2024-10-03T00:00:00.000Z',
#      'RawVOName': 'https://cilogon.org/fermilab',
#      'OIM_FQDN': 'osggrid01.hep.wisc.edu',
#      'RawOIM_Site': ''},
#     'sort': [1727913600000]}]}}
